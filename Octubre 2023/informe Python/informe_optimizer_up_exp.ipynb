# %%
import pandas as pd
import numpy as np
import matplotlib as mtplp

# %%
file_path = "xls optimizer ocubtre.xls"

with open(file_path, "r", encoding= "utf-8") as file: content = file.read()

content
# Out:
# '<html xmlns:o="urn:schemas-microsoft-com:office:office" xmlns:x="urn:schemas-microsoft-com:office:excel" xmlns="http://www.w3.org/TR/REC-html40"><head><meta name=ProgId content=Excel.Sheet> <meta name=Generator content="Microsoft Excel 11"><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><!--[if gte mso 9]><xml><x:ExcelWorkbook><x:ExcelWorksheets><x:ExcelWorksheet><x:Name>Sheet1</x:Name><x:WorksheetOptions><x:DisplayGridlines/></x:WorksheetOptions></x:ExcelWorksheet></x:ExcelWorksheets></x:ExcelWorkbook></xml><![endif]--><style>br {mso-data-placement: same-cell;}</style></head><body><table><thead><tr><th>Actions</th><th>Name</th><th>Status</th><th>Cost</th><th>Publisher Revenue</th><th>Profit</th><th>ROI</th><th>CPA</th><th>EPA</th></tr></thead><tbody><tr><td></td><td>S1 - CL - Credito Negocios - prestamos-para-negocios-intl.xyz</td><td>RUNNING</td><td>1241.2600000000002</td><td>2081.5599999999995</td><td>840.2999999999993</td><td>67.6973397998807</td><td>0.1364771
# ...

# %%
#segun chatgpt

dfs = pd.read_html(content, flavor='lxml')

df = dfs[0]

print(df.head())
# Out:
#    Actions                                               Name   Status  \
# 0      NaN  S1 - CL - Credito Negocios - prestamos-para-ne...  RUNNING
# 1      NaN  S1 - COL - Credito Negocios - prestamos-para-n...  RUNNING
# 2      NaN  S1 - CR - Subsidio vivienda - subsidios-del-go...  RUNNING
# 3      NaN  S1 - UGA - Prestamos estatales - state-loans-i...  RUNNING
# 4      NaN  S1 - PA - Préstamos estatales - prestamos-esta...  RUNNING
#
#       Cost  Publisher Revenue  Profit        ROI       CPA       EPA
# 0  1241.26            2081.56  840.30  67.697340  0.136477  0.228869
# 1   701.82            1234.91  533.09  75.958223  0.102967  0.181178
# 2   514.25             673.91  159.66  31.047156  0.070033  0.091776
# 3   358.41             521.43  163.02  45.484222  0.102549  0.149193
# 4   264.57             328.03   63.46  23.986091  0.046993  0.058265

# %%
df.dtypes
# Out:
# Actions              float64
# Name                  object
# Status                object
# Cost                 float64
# Publisher Revenue    float64
# Profit               float64
# ROI                  float64
# CPA                  float64
# EPA                  float64
# dtype: object

# %%
# check df shape
print(df.shape)
# Out:
# (442, 9)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Actions            0 non-null      float64
#  1   Name               442 non-null    object
#  2   Status             442 non-null    object
#  3   Cost               442 non-null    float64
#  4   Publisher Revenue  442 non-null    float64
#  5   Profit             442 non-null    float64
#  6   ROI                442 non-null    float64
#  7   CPA                442 non-null    float64
#  8   EPA                442 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 31.2+ KB
# None

# %%
print(df.isnull().sum())
# Out:
# Actions              442
# Name                   0
# Status                 0
# Cost                   0
# Publisher Revenue      0
# Profit                 0
# ROI                    0
# CPA                    0
# EPA                    0
# dtype: int64

# %%
df2 = df.sort_values(by=["Profit"])
lowest = df.head(5)
highest = df.tail(5)

print("------------------")

print(lowest)

print("------------------")

print(highest)
# Out:
# ------------------
#    Actions                                               Name   Status  \
# 0      NaN  S1 - CL - Credito Negocios - prestamos-para-ne...  RUNNING
# 1      NaN  S1 - COL - Credito Negocios - prestamos-para-n...  RUNNING
# 2      NaN  S1 - CR - Subsidio vivienda - subsidios-del-go...  RUNNING
# 3      NaN  S1 - UGA - Prestamos estatales - state-loans-i...  RUNNING
# 4      NaN  S1 - PA - Préstamos estatales - prestamos-esta...  RUNNING
#
#       Cost  Publisher Revenue  Profit        ROI       CPA       EPA
# 0  1241.26            2081.56  840.30  67.697340  0.136477  0.228869
# 1   701.82            1234.91  533.09  75.958223  0.102967  0.181178
# 2   514.25             673.91  159.66  31.047156  0.070033  0.091776
# 3   358.41             521.43  163.02  45.484222  0.102549  0.149193
# 4   264.57             328.03   63.46  23.986091  0.046993  0.058265
# ------------------
#      Actions                                               Name  Status  Cost  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                      0        1      2      3  \
# 0                                                 Name   Status    NaN    NaN
# 1    S1 - CL - Credito Negocios - prestamos-para-ne...  RUNNING  34.35  75.78
# 2    S1 - CR - Subsidio vivienda - subsidios-del-go...  RUNNING  25.38  43.66
# 3    S1 - COL - Credito Negocios - prestamos-para-n...  RUNNING  19.14  48.85
# 4    S1 - UGA - Prestamos estatales - state-loans-i...  RUNNING  12.82  18.38
# ..                                                 ...      ...    ...    ...
# 424  S1 - MEX - Credito Negocios - prestamos-para-n...   PAUSED   0.00   0.00
# 425  S1 - ALB - Prestamos estatales - state-loans-i...   PAUSED   0.00   0.00
# 426  S1 - GUI ECU - Refinanciamiento deuda - refina...   PAUSED   0.00   0.00
# 427  S1 - CL - Joyas Oro Remate - liquidacion-de-jo...   PAUSED   0.00   0.00
# 428  S1 - UY - Bonos Gobierno - bonos-del-gobierno.xyz   PAUSED   0.00   0.00
#
# ...

# %%
# nuevo df con revenue separado de los que tienen 0
df_revenue = df["Profit"] >= 1
df_revenue_filtrado = df[df_revenue]
print(df_revenue_filtrado)
# Out:
#      Actions                                               Name   Status  \
# 0        NaN  S1 - CL - Credito Negocios - prestamos-para-ne...  RUNNING
# 1        NaN  S1 - COL - Credito Negocios - prestamos-para-n...  RUNNING
# 2        NaN  S1 - CR - Subsidio vivienda - subsidios-del-go...  RUNNING
# 3        NaN  S1 - UGA - Prestamos estatales - state-loans-i...  RUNNING
# 4        NaN  S1 - PA - Préstamos estatales - prestamos-esta...  RUNNING
# ..       ...                                                ...      ...
# 89       NaN  S1 - NIGE - Cursos tecnicos online - online-te...  RUNNING
# 90       NaN  S1 - TRI & TOB - Cursos tecnicos online - onli...  RUNNING
# 92       NaN  S1 - PA - Joyas Oro Remate - liquidacion-de-jo...  RUNNING
# 94       NaN  S1 - MEX - Tarjetas de Credito - tarjetas-de-c...   PAUSED
# 118      NaN  S1 - SAL - Prestamos Rapidos - prestamos-onlin...  RUNNING
#
#         Cost  Publisher Revenue  Profit        ROI       CPA       EPA
# ...

# %%
# nuevo df con gasto separado de los que tienen 0 (no han gastado nada)
df_gasto = df["Cost"] >= 1
df_gasto_filtrado = df[df_gasto]
print(df_gasto_filtrado)
# Out:
#      Actions                                               Name   Status  \
# 0        NaN  S1 - CL - Credito Negocios - prestamos-para-ne...  RUNNING
# 1        NaN  S1 - COL - Credito Negocios - prestamos-para-n...  RUNNING
# 2        NaN  S1 - CR - Subsidio vivienda - subsidios-del-go...  RUNNING
# 3        NaN  S1 - UGA - Prestamos estatales - state-loans-i...  RUNNING
# 4        NaN  S1 - PA - Préstamos estatales - prestamos-esta...  RUNNING
# ..       ...                                                ...      ...
# 115      NaN  S1 - PA - Microcredito Personal - microcredito...  RUNNING
# 116      NaN  S1 - COL - Becas Usa - scholarships-to-study-i...  RUNNING
# 117      NaN  S1 - MEX - Curso IA Gratis - cursos-de-ia-grat...   PAUSED
# 118      NaN  S1 - SAL - Prestamos Rapidos - prestamos-onlin...  RUNNING
# 119      NaN  S1 - UY - Curso IA Gratis - cursos-de-ia-grati...   PAUSED
#
#         Cost  Publisher Revenue  Profit        ROI       CPA       EPA
# ...

# %%
# nuevo df con gasto y profit igual a 0
df_gasto0_profit0 = (df["Cost"] == 0) & (df["Profit"] == 0)
df_gasto0__profit0_filtrado = df[df_gasto0_profit0]
print(df_gasto0_profit0)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 437     True
# 438     True
# 439     True
# 440     True
# 441     True
# Length: 442, dtype: bool

# %%
df.columns
# Out:
# Index([0, 1, 2, 3, 4, 5, 6, 7], dtype='int64')

# %%
df.rename(columns={ "Name": "Dominios" })

df.columns
# Out:
# Index([0, 1, 2, 3, 4, 5, 6, 7], dtype='int64')
